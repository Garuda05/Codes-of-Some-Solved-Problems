# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('D:/Downloads/F.jpg')
image_k =img
image_k
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x500 at 0x1D52DDD6688>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imga= np.asarray(img)

# %%
type(imga)
# Out:
# numpy.ndarray

# %%
imga.shape
# Out:
# (500, 400, 3)

# %%
plt.imshow(imga)

# %%
img2=imga.copy()
img3=imga.copy()
img4=imga.copy()

imga
# Out:
# array([[[121,  92,  78],
#         [121,  92,  78],
#         [121,  92,  78],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[121,  92,  78],
#         [121,  92,  78],
#         [121,  92,  78],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[122,  93,  79],
#         [122,  93,  79],
#         [121,  92,  78],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        ...,
#
#        [[ 66,  47,  33],
#         [ 67,  48,  34],
#         [ 67,  48,  34],
#         ...,
#         [ 79,  36,  30],
#         [ 81,  36,  31],
#         [ 81,  36,  31]],
#
#        [[ 66,  47,  33],
#         [ 66,  47,  33],
#         [ 67,  48,  34],
#         ...,
#         [ 79,  36,  30],
#         [ 81,  36,  31],
#         [ 81,  36,  31]],
#
#        [[ 66,  47,  33],
#         [ 66,  47,  33],
#         [ 67,  48,  34],
# ...

# %%
img2[:,:,0]
# Out:
# array([[121, 121, 121, ...,   3,   3,   3],
#        [121, 121, 121, ...,   3,   3,   3],
#        [122, 122, 121, ...,   3,   3,   3],
#        ...,
#        [ 66,  67,  67, ...,  79,  81,  81],
#        [ 66,  66,  67, ...,  79,  81,  81],
#        [ 66,  66,  67, ...,  79,  81,  81]], dtype=uint8)

# %%
plt.imshow(img2[:,:,0])

# %%
plt.imshow(img2[:,:,1])

# %%
plt.imshow(img2[:,:,2])

# %%
plt.imshow(img2[:,:,0], cmap='gray')

# %%
plt.imshow(img2[:,:,1], cmap='gray')

# %%
img2[:,:,1]=0
img2[:,:,2]=0

# %%
plt.imshow(img2)

# %%
img4[:,:,0]=0
img4[:,:,1]=0

# %%
plt.imshow(img4)
